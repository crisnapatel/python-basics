# %% [markdown]
# # Python Playground
#
# Welcome! Run cells with Shift+Enter

# %%
print("Hello, Chemical Engineer!")

# %%
# Parachutist problem
m = 68.1
g = 9.8
c = 12.5
v_terminal = (m * g) / c
print(f"Terminal velocity: {v_terminal:.2f} m/s")
